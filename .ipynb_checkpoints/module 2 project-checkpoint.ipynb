# %%
import numpy as np
import pandas as pd
# import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds=pd.read_csv('data/diamonds_train.csv')
diamonds['total_depth'] = 2 * diamonds['z'] / (diamonds['x'] + diamonds['y']) 

cut_dict={'Ideal':5,
'Premium':4,
'Very Good':3,
'Good':2,
'Fair':1}

clarity_dict={'IF':8,
'VVS1':7,
'VVS2':6,
'VS1':5,
'VS2':4,
'SI1':3,
'SI2':2,
'I1':1}

diamonds['num_cut']=diamonds.cut.apply(lambda x: cut_dict[x])
diamonds['num_clarity']=diamonds.clarity.apply(lambda x: clarity_dict[x])

# %%
diamonds.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
#
#    total_depth  num_cut  num_clarity
# 0     0.624082        4            4
# 1     0.630011        3            4
# 2     0.654709        1            5
# 3     0.638298        2            3
# 4     0.604900        5            3

# %% [markdown]
# price: price in USD
#
# carat: weight of the diamond
#
# cut: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# color: diamond colour, from J (worst) to D (best)
#
# clarity: a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# x: length in mm
#
# y: width in mm
#
# z: depth in mm
#
# depth: total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# table: width of top of diamond relative to widest point (43--95)

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40455 non-null  float64
#  1   cut      40455 non-null  object
#  2   color    40455 non-null  object
#  3   clarity  40455 non-null  object
#  4   depth    40455 non-null  float64
#  5   table    40455 non-null  float64
#  6   price    40455 non-null  int64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean       0.797706     61.752841     57.446133   3928.444469      5.729392
# std        0.475544      1.431725      2.233535   3992.416147      1.124453
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    945.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2397.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5331.000000      6.540000
# max        4.500000     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z   total_depth       num_cut   num_clarity
# count  40455.000000  40455.000000  40451.000000  40455.000000  40455.000000
# mean       5.732819      3.537154      0.617350      3.904783      4.049388
# std        1.146650      0.697062      0.018370      1.117876      1.648181
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%        4.720000      2.910000      0.610417      3.000000      3.000000
# 50%        5.710000      3.520000      0.618391      4.000000      4.000000
# 75%        6.540000      4.035000      0.625282      5.000000      5.000000
# max       58.900000      8.060000      1.006965      5.000000      8.000000

# %%
diamonds[diamonds.total_depth.isnull()]
# Out:
#        carat      cut color clarity  depth  table  price    x    y    z  \
# 6465    0.71     Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0
# 26192   2.25  Premium     H     SI2   62.8   59.0  18034  0.0  0.0  0.0
# 28029   0.71     Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0
# 34423   1.14     Fair     G     VS1   57.5   67.0   6381  0.0  0.0  0.0
#
#        total_depth  num_cut  num_clarity
# 6465           NaN        2            2
# 26192          NaN        4            2
# 28029          NaN        2            2
# 34423          NaN        1            5

# %%
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
# diamonds['cut'].value_counts()
fig,ax = plt.subplots(figsize=(8, 5))
sns.histplot(data=diamonds, x='num_cut', hue='color', multiple="stack",discrete=True)
print(cut_dict)
# Out:
# {'Ideal': 5, 'Premium': 4, 'Very Good': 3, 'Good': 2, 'Fair': 1}

# %%
# diamonds['color'].value_counts()
fig,ax = plt.subplots(figsize=(8, 5))
sns.histplot(data=diamonds, x='color', hue='clarity', multiple="stack")
# Out:
# <AxesSubplot:xlabel='color', ylabel='Count'>

# %%
diamonds['clarity'].value_counts()
# Out:
# SI1     9749
# VS2     9248
# SI2     6929
# VS1     6066
# VVS2    3799
# VVS1    2774
# IF      1327
# I1       563
# Name: clarity, dtype: int64

# %%
fig1,ax1= plt.subplots(ncols=6, figsize=(24,4))
list_col=['carat','depth', 'table','total_depth','num_cut','num_clarity']
for i in range(len(list_col)):
    ax1[i].scatter(x=diamonds[list_col[i]], y=diamonds.price)
    ax1[i].set_title(list_col[i])

# %%
color_list=list(diamonds['color'].unique())

fig_color,ax_color= plt.subplots(ncols=6,nrows=7,  figsize=(24,28))
# list_col=['carat','depth', 'table','total_depth','num_cut','num_clarity']
j=0

for color in color_list:
    filter_by_color=diamonds[diamonds['color']==color]
#     fig_color.suptitle(color)
    for i in range(len(list_col)):
        ax_color[j][i].scatter(x=filter_by_color[list_col[i]], y=filter_by_color.price)
        ax_color[j][i].set_title(list_col[i])
    j+=1

# %%
cut_list=list(diamonds['cut'].unique())

fig_cut,ax_cut= plt.subplots(ncols=6,nrows=5,  figsize=(24,28))
# list_col=['carat','depth', 'table','total_depth','num_cut','num_clarity']
j=0

for color in color_list:
    filter_by_color=diamonds[diamonds['color']==color]
#     fig_color.suptitle(color)
    for i in range(len(list_col)):
        ax_color[j][i].scatter(x=filter_by_color[list_col[i]], y=filter_by_color.price)
        ax_color[j][i].set_title(list_col[i])
    j+=1

# %%
fig_box,ax_box = plt.subplots(figsize=(8, 8))
ax_box = sns.boxplot(x='num_cut', y='price', data=diamonds)
print(cut_dict)
# Out:
# {'Ideal': 5, 'Premium': 4, 'Very Good': 3, 'Good': 2, 'Fair': 1}

# %%
fig_box,ax_box = plt.subplots(figsize=(8, 8))
ax_box = sns.boxplot(x='num_clarity', y='price', data=diamonds)
print(clarity_dict)
# Out:
# {'IF': 8, 'VVS1': 7, 'VVS2': 6, 'VS1': 5, 'VS2': 4, 'SI1': 3, 'SI2': 2, 'I1': 1}

# %%
fig_box,ax_box = plt.subplots(figsize=(8, 8))
ax_box = sns.boxplot(x='color', y='price', data=diamonds)

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(data=diamonds.select_dtypes(include=['float64','int64']).corr(), vmax=1, vmin=-1, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# Logico que tenga una fuerte correlacion entre price, x,y,z con carat (peso), a traves del volumen.
# Sorprende la baja correlación (negativa) entre cut y clarity con el precio

# %%
diamonds.groupby('color').mean()
# Out:
#           carat      depth      table        price         x         y  \
# color
# D      0.653036  61.721886  57.344959  3134.943157  5.404704  5.409541
# E      0.658835  61.659836  57.494567  3088.342526  5.413894  5.418651
# F      0.731503  61.689954  57.409726  3677.355720  5.601393  5.607254
# G      0.774382  61.752785  57.287889  4023.214902  5.684102  5.687183
# H      0.910355  61.827481  57.533503  4476.469014  5.981431  5.984082
# I      1.026791  61.873214  57.562574  5090.868800  6.216099  6.215675
# J      1.166500  61.909626  57.790701  5346.234112  6.527285  6.525570
#
#               z  total_depth   num_cut  num_clarity
# color
# D      3.336782     0.617239  3.935037     3.705090
# E      3.338709     0.616531  3.893242     3.968874
# F      3.455930     0.616657  3.897032     4.134039
# G      3.508856     0.617272  3.989355     4.458309
# H      3.693629     0.617917  3.876374     3.942011
# I      3.842078     0.618487  3.858631     3.942956
# J      4.039879     0.619237  3.735047     3.753271

# %%
diamonds.groupby('cut').mean()
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.047305  64.051438  59.022104  4333.271980  6.248825  6.184289
# Good       0.844565  62.407699  58.652307  3880.611794  5.824797  5.836140
# Ideal      0.700337  61.703206  55.952990  3436.112577  5.500933  5.512639
# Premium    0.896125  61.261082  58.737076  4617.322612  5.982015  5.954603
# Very Good  0.808056  61.824794  57.956031  3994.444420  5.743912  5.773269
#
#                   z  total_depth  num_cut  num_clarity
# cut
# Fair       3.985193     0.641103      1.0     3.007395
# Good       3.632361     0.623689      2.0     3.596506
# Ideal      3.396982     0.616901      5.0     4.460789
# Premium    3.651374     0.612184      4.0     3.734795
# Very Good  3.559988     0.618249      3.0     3.992413

# %%
diamonds.groupby('clarity').mean()
# Out:
#             carat      depth      table        price         x         y  \
# clarity
# I1       1.299591  62.804796  58.237478  3971.206039  6.782771  6.729485
# IF       0.499849  61.511454  56.496684  2797.897513  4.953451  4.975011
# SI1      0.851174  61.859668  57.648549  3999.856908  5.888604  5.888270
# SI2      1.081472  61.779954  57.909150  5101.044307  6.408255  6.407433
# VS1      0.721553  61.678948  57.285410  3796.813551  5.555437  5.562798
# VS2      0.762661  61.721345  57.404520  3913.590182  5.655557  5.656696
# VVS1     0.506994  61.606921  56.929740  2559.498558  4.973554  4.988504
# VVS2     0.591777  61.658884  57.031561  3240.978942  5.206976  5.220753
#
#                 z  total_depth   num_cut  num_clarity
# clarity
# I1       4.227318     0.626059  2.969805          1.0
# IF       3.052427     0.615033  4.442351          8.0
# SI1      3.639990     0.618429  3.742435          3.0
# SI2      3.952679     0.617308  3.660268          2.0
# VS1      3.428205     0.616797  4.013188          5.0
# VS2      3.489658     0.617108  3.985619          4.0
# VVS1     3.068893     0.616171  4.222783          7.0
# VVS2     3.213917     0.616505  4.116083          6.0

# %%
print(clarity_dict)
# Out:
# {'IF': 8, 'VVS1': 7, 'VVS2': 6, 'VS1': 5, 'VS2': 4, 'SI1': 3, 'SI2': 2, 'I1': 1}
